# %%
import os
import glob
import re
import pandas as pd

# %%
# Reading csv files from ETF_data folder
csv_files = glob.glob(os.path.join("ETF_data", "*.csv"))
df_list = []

# For each csv file extract the ETF name using regex and add the name to the a new column called "ETF"
# Add each csv file to df_list
for file in csv_files:
    df = pd.read_csv(file)
    match = re.search(r"/([^/]+)\.csv$", file)
    if match:
        ETF_str = match.group(1)
        df["ETF"] = ETF_str
    df_list.append(df)

# Remove any empty data frames
df_list = [df for df in df_list if not df.empty]

# Combine all data frames into one master data frame
master_df = pd.concat(df_list, ignore_index=True)
master_df
# Out:
#                 Date   Adj Close       Close        High         Low  \
# 0         2007-11-07  418.000000  418.000000  454.200012  384.000000
# 1         2007-11-08  380.000000  380.000000  407.000000  370.000000
# 2         2007-11-09  388.000000  388.000000  394.600006  364.000000
# 3         2007-11-12  371.200012  371.200012  386.000000  360.000000
# 4         2007-11-13  360.000000  360.000000  377.600006  360.000000
# ...              ...         ...         ...         ...         ...
# 18387217  2025-01-30   50.630001   50.630001   52.270000   48.650002
# 18387218  2025-01-31   50.419998   50.419998   52.139999   50.395000
# 18387219  2025-02-03   48.599998   48.599998   49.430000   47.750000
# 18387220  2025-02-04   49.750000   49.750000   50.340000   47.660000
# 18387221  2025-02-05   46.970001   46.970001   48.950001   46.700001
#
#                 Open     Volume   ETF
# 0         390.000000   595380.0  ANTE
# 1         390.000000   162105.0  ANTE
# 2         370.000000    84805.0  ANTE
# 3         360.000000    62680.0  ANTE
# 4         366.200012    90480.0  ANTE
# ...              ...        ...   ...
# 18387217   50.029999  4578200.0   NXT
# 18387218   51.130001  2389700.0   NXT
# 18387219   48.320000  2570700.0   NXT
# 18387220   48.820000  2268300.0   NXT
# 18387221   48.590000  5242265.0   NXT
#
# [18387222 rows x 8 columns]

# %%
# Data inspection
print(master_df.shape)
print(master_df.columns.tolist())
master_df.head()
# Out:
# (18387222, 8)
# ['Date', 'Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume', 'ETF']
#          Date   Adj Close       Close        High    Low        Open  \
# 0  2007-11-07  418.000000  418.000000  454.200012  384.0  390.000000
# 1  2007-11-08  380.000000  380.000000  407.000000  370.0  390.000000
# 2  2007-11-09  388.000000  388.000000  394.600006  364.0  370.000000
# 3  2007-11-12  371.200012  371.200012  386.000000  360.0  360.000000
# 4  2007-11-13  360.000000  360.000000  377.600006  360.0  366.200012
#
#      Volume   ETF
# 0  595380.0  ANTE
# 1  162105.0  ANTE
# 2   84805.0  ANTE
# 3   62680.0  ANTE
# 4   90480.0  ANTE

# %%
summary_stats = master_df.groupby('ETF').describe().round(2)
print("\nSummary Statistics by ETF:")
summary_stats
# Out:
# Summary Statistics by ETF:
#      Adj Close                                                           \
#          count     mean      std    min    25%    50%      75%      max
# ETF
# A       6342.0    49.55    42.40   6.54  19.86  30.32    66.19   175.16
# AAA     1108.0    22.22     1.30  20.85  21.25  21.40    23.36    25.13
# AAAU    1628.0    18.14     3.51  11.74  16.31  18.05    19.45    28.31
# AADR    3660.0    42.41    12.19  21.78  32.88  42.35    52.06    75.32
# AAL     4871.0    23.29    14.76   1.66  11.06  18.07    36.37    59.35
# ...        ...      ...      ...    ...    ...    ...      ...      ...
# ZVRA    2468.0    53.21    80.04   2.75   5.80  10.77    65.60   378.08
# ZVSA     748.0  1096.41  1539.57   1.00   5.43  56.52  3458.00  7875.00
# ZYBT      20.0     4.46     0.17   4.21   4.34   4.46     4.55     4.86
# ZYME    1955.0    18.35    12.65   4.65   8.43  13.11    28.03    56.81
# ZYXI    5272.0     3.45     4.88   0.08   0.24   0.48     7.36    25.70
#
#        Close           ...     Open           Volume               \
#        count     mean  ...      75%      max   count         mean
# ETF                    ...
# A     6342.0    52.50  ...    69.55   179.28  6342.0   3312193.93
# AAA   1108.0    24.85  ...    25.06    25.40  1108.0      4402.20
# AAAU  1628.0    18.14  ...    19.45    28.35  1628.0    940626.44
# AADR  3660.0    45.57  ...    55.30    75.27  3660.0      8010.54
# AAL   4871.0    24.15  ...    38.00    62.70  4871.0  16154541.47
# ...      ...      ...  ...      ...      ...     ...          ...
# ZVRA  2468.0    53.21  ...    64.80   380.64  2468.0    290184.59
# ZVSA   748.0  1096.41  ...  3458.00  4900.00   748.0    224888.63
# ZYBT    20.0     4.46  ...     4.51     4.81    20.0    238109.55
# ZYME  1955.0    18.35  ...    27.81    57.31  1955.0    491170.53
# ZYXI  5272.0     3.67  ...     7.39    26.05  5272.0    135135.26
#
#
#               std       min         25%        50%          75%          max
# ETF
# A      2389285.69  271900.0  1806678.75  2803874.0   4145699.25   62546380.0
# AAA      10863.08       0.0      200.00     1050.0      4400.00     182900.0
# AAAU   1174417.85     100.0   160450.00   512350.0   1385675.00   14338200.0
# AADR     16666.03       0.0      600.00     2000.0      7300.00     323800.0
# AAL   21927577.85  138500.0  4950850.00  8385400.0  20216000.00  428617100.0
# ...           ...       ...         ...        ...          ...          ...
# ZVRA   1453731.93       0.0     4854.50    33887.5    256967.00   59212000.0
# ZVSA   2751488.05       0.0       39.25     4356.0     38100.00   63497900.0
# ZYBT    434425.32   11691.0    21575.00    46600.0    307000.00    1864900.0
# ZYME   1035755.84     500.0   146700.00   347600.0    584750.00   36641400.0
# ZYXI    312579.56       0.0     4400.00    24420.0    141487.50    6783480.0
#
# [6691 rows x 48 columns]

# %%
import matplotlib.pyplot as plt

# %%
etf_names = master_df['ETF'].unique()
for etf in etf_names:
    if (etf != "VOO"):
        continue;
    df_etf = master_df[master_df['ETF'] == etf].copy()
    df_etf.sort_values('Date', inplace=True)
    
    plt.figure(figsize=(8, 4))
    plt.plot(df_etf['Date'], df_etf['Adj Close'])
    plt.title(f"Closing Price Over Time - {etf}")
    plt.xlabel("Date")
    plt.ylabel("Adj Close Price")
    plt.tight_layout()
    if (etf == "VOO"):
        plt.show()
